# %% [markdown]
# # TopoLS Tutorial

# %% [markdown]
# ### Step 1: Compile a quantum circuit using TopoLS

# %%
# Let's compile 16 qubits GHZ circuit
# !python3 prog.py -f ghz_16 -b 20 -zx 1 -dir 1 -l 4 -r 0 -s 2 -t 2 -i 1000 -csv result -sp 0 -b0 0
# Compilation results are saved in result/topols/

# %% [markdown]
# #### We explain the arguments here.
#
# -b: Maximum block size for circuit slicing. Although a topology-aware partitioning is used, this argument specifies the upper limit on the size of each block.
#
# -zx: ZX optimization level (0: off, 1: on). Enabling this option activates spider fusion.
#
# -dir: Direction optimization level (0: off, 1: on). Enable this option activates placement exploration in MCTS embedding.
#
# -l: Qubit number per row. Logical qubits are initially placed in a rectangular layout, and this value specifies how many logical qubits are placed in each row.
#
# -r: Initial random seed for circuit compilation.
#
# -s: Number of random seed will be tried.
#
# -t: Time bound for each MCTS iteration (second).
#
# -i: Number of iterations for MCTS.
#
# -csv: csv result file name, saved in result/topols/.
#
# #### If the circuit is too dense:
#
# -sp: For dense circuit we will spread the quantum gates into different rows. This parameter specifies how many gates are placed in each row. In such cases, it is also recommended to reduce -b to 1 or 2.
#
# -b0: Inforce the first row of circuit as a block (0: off, 1: on).

# %%
# Dense circuit example
# !python3 prog.py -f random_500 -b 1 -zx 1 -dir 1 -l 23 -r 0 -s 2 -t 5 -i 1000 -csv result -sp 70 -b0 0
# The baseline method (DASCOT) achieves a z-length of 43, whereas our method reduces it to 19 with the same spatial footprint, representing a significant improvement.

# %% [markdown]
# ### Step 2: Transform to tqec bgraph format, and visualization

# %%
# Using 2tqec to transpile the TopoLS compilation result to a TQEC readable format, and visualize the TQEC schedule
# -f specifies the filename of the .pkl file to be used for translation, -p specifies whether to visualize the TQEC schedule. The .png file of the pipe diagram is saved in result/visualizatioin/
# !python3 2tqec.py -f ghz_16 -p True
# !python3 2tqec.py -f random_500 -p True

# %% [markdown]
# ### Step 3: Simulate our pipe using TQEC
# Note: TQEC is still developing methods for simulating S, T, and (in some cases) H gates.
#
# Therefore, we recommend simulating only circuits composed of CNOT gates.

# %%
# Given the runtime constraints, we only simulate a CNOT here.
# !python3 prog.py -f CNOT -b 20 -zx 1 -dir 1 -l 4 -r 0 -s 2 -t 2 -i 1000 -csv result -sp 0 -b0 0
# !python3 2tqec.py -f CNOT -p True

# -f specifies the filename of the .bgraph file to be simulated, which is generated by 2tqec.py. The .bgraph file should be placed in result/bgraph/ directory.
# Simulation results are saved in result/simulation/
# !python3 pipe_sim.py -f CNOT
# Out:
# Executing CNOT benchmark.
# Embedding progress:
#  50%|██████████████████████▌                      | 1/2 [00:00<00:00,  3.99it/s]
# x_length: 5.0 y_length: 3.0 z_length: 2
# Space-time volume: 30.0
# Time: 2
# Space: 15.0
# Compilation time: 0.2517368793487549
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 429.85it/s]
# 100%|██████████████████████████████████████████| 11/11 [00:00<00:00, 418.75it/s]
# Figure(1800x1800)
# Computing minimum fill of ports to reduce simulation times.
# Performing simulations...
# Starting 16 workers...
# 30 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.00021544346900318845
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.00046415888336127773
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.001
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.002154434690031882
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.004641588833612777
#         1 pymatching <1m     998703        9655 d=3,r=3,p=0.01
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.021544346900318822
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.046415888336127774
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.1
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.0001
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.00021544346900318845
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.00046415888336127773
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.001
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.002154434690031882
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 30 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     944431        9959 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     955695        9836 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     970031        9507 d=3,r=3,p=0.001
#         1 pymatching <1m     984367        8952 d=3,r=3,p=0.002154434690031882
#         1 pymatching <1m     991535        8366 d=3,r=3,p=0.004641588833612777
#         1 pymatching <1m     994607        8640 d=3,r=3,p=0.01
#         1 pymatching <1m     998703        9656 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     998703        9650 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     999727        9928 d=3,r=3,p=0.1
#         1 pymatching <1m     998703       10000 d=5,r=5,p=0.0001
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.00021544346900318845
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.00046415888336127773
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.001
#         1 pymatching <1m     999727        9981 d=5,r=5,p=0.002154434690031882
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 30 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     872751        9896 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     897327        9578 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     933167        8827 d=3,r=3,p=0.001
#         1 pymatching <1m     964911        7582 d=3,r=3,p=0.002154434690031882
#         1 pymatching <1m     982319        6622 d=3,r=3,p=0.004641588833612777
#         1 pymatching <1m     992559        8110 d=3,r=3,p=0.01
#         1 pymatching <1m     996655        9105 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     997679        9397 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     998703        9692 d=3,r=3,p=0.1
#         1 pymatching <1m     984367       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     991535        9998 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     993583        9992 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     995631        9976 d=5,r=5,p=0.001
#         1 pymatching <1m     996655        9837 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     999727        9940 d=5,r=5,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 30 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     813359        9840 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     850223        9377 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     902447        8297 d=3,r=3,p=0.001
#         1 pymatching <1m     948527        6462 d=3,r=3,p=0.002154434690031882
#         1 pymatching <1m     975151        5275 d=3,r=3,p=0.004641588833612777
#         1 pymatching <1m     985391        6274 d=3,r=3,p=0.01
#         1 pymatching <1m     995631        8863 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     995631        8900 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     997679        9421 d=3,r=3,p=0.1
#         1 pymatching <1m     963887       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     979247        9998 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     984367        9985 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     990511        9941 d=5,r=5,p=0.001
#         1 pymatching <1m     992559        9639 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     997679        9489 d=5,r=5,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 30 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     729391        9758 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     784687        9093 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     860463        7573 d=3,r=3,p=0.001
#         1 pymatching <1m     925999        4859 d=3,r=3,p=0.002154434690031882
#         1 pymatching <1m     964911        3282 d=3,r=3,p=0.004641588833612777
#         1 pymatching <1m     985391        6274 d=3,r=3,p=0.01
#         1 pymatching <1m     991535        7832 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     994607        8617 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     995631        8894 d=3,r=3,p=0.1
#         1 pymatching <1m     947503       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     955695        9997 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     966959        9968 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     980271        9873 d=5,r=5,p=0.001
#         1 pymatching <1m     989487        9506 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     996655        9280 d=5,r=5,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 30 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     610607        9647 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     784687        9093 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     801071        6513 d=3,r=3,p=0.001
#         1 pymatching <1m     925999        4859 d=3,r=3,p=0.002154434690031882
#         1 pymatching <1m     964911        3282 d=3,r=3,p=0.004641588833612777
#         1 pymatching <1m     980271        5030 d=3,r=3,p=0.01
#         1 pymatching <1m     991535        7832 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     992559        8094 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     994607        8625 d=3,r=3,p=0.1
#         1 pymatching <1m     924975       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     937263        9997 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     953647        9961 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     980271        9873 d=5,r=5,p=0.001
#         1 pymatching <1m     985391        9311 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     995631        9058 d=5,r=5,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 29 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     610607        9647 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     692527        8717 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     801071        6513 d=3,r=3,p=0.001
#         1 pymatching <1m     894255        2717 d=3,r=3,p=0.002154434690031882
#         1 pymatching <1m     973103        3190 d=3,r=3,p=0.01
#         1 pymatching <1m     988463        7082 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     992559        8094 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     993583        8374 d=3,r=3,p=0.1
#         1 pymatching <1m     893231       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     937263        9997 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     953647        9961 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     972079        9815 d=5,r=5,p=0.001
#         1 pymatching <1m     985391        9311 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     994607        8838 d=5,r=5,p=0.004641588833612777
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 29 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         1 pymatching          ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching        <1m     444719        9516 d=3,r=3,p=0.00021544346900318845
#         1 pymatching        <1m     692527        8717 d=3,r=3,p=0.00046415888336127773
#         1 pymatching        <1m     719151        5100 d=3,r=3,p=0.001
#         1 pymatching [draining]     854319         -54 d=3,r=3,p=0.002154434690031882
#         1 pymatching        <1m     973103        3190 d=3,r=3,p=0.01
#         1 pymatching        <1m     984367        6058 d=3,r=3,p=0.021544346900318822
#         1 pymatching        <1m     990511        7543 d=3,r=3,p=0.046415888336127774
#         1 pymatching        <1m     993583        8374 d=3,r=3,p=0.1
#         1 pymatching        <1m     893231       10000 d=5,r=5,p=0.0001
#         1 pymatching        <1m     911663        9995 d=5,r=5,p=0.00021544346900318845
#         1 pymatching        <1m     935215        9949 d=5,r=5,p=0.00046415888336127773
#         1 pymatching        <1m     960815        9746 d=5,r=5,p=0.001
#         1 pymatching        <1m     979247        9029 d=5,r=5,p=0.002154434690031882
#         1 pymatching        <1m     992559        8415 d=5,r=5,p=0.004641588833612777
#         1 pymatching          ?    1000000       10000 d=5,r=5,p=0.01
#         0 pymatching        ?·∞    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching        ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching        ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching        ?·∞    1000000       10000 d=7,r=7,p=0.1
# 28 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     444719        9516 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     565551        8186 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     719151        5100 d=3,r=3,p=0.001
#         1 pymatching <1m     962863         571 d=3,r=3,p=0.01
#         1 pymatching <1m     984367        6058 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     990511        7543 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     991535        7853 d=3,r=3,p=0.1
#         1 pymatching <1m     893231       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     911663        9995 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     935215        9949 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     960815        9746 d=5,r=5,p=0.001
#         1 pymatching <1m     979247        9029 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     992559        8415 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     999727        9934 d=5,r=5,p=0.01
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 27 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     444719        9516 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     565551        8186 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     719151        5100 d=3,r=3,p=0.001
#         1 pymatching <1m     984367        6058 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     987439        6716 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     991535        7853 d=3,r=3,p=0.1
#         1 pymatching <1m     849199       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     875823        9994 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     909615        9933 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     945455        9669 d=5,r=5,p=0.001
#         1 pymatching <1m     979247        9029 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     990511        7984 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     999727        9934 d=5,r=5,p=0.01
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.021544346900318822
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 27 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     213295        9329 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     565551        8186 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     603439        3088 d=3,r=3,p=0.001
#         1 pymatching <1m     979247        4763 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     987439        6716 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     989487        7376 d=3,r=3,p=0.1
#         1 pymatching <1m     849199       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     875823        9994 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     909615        9933 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     945455        9669 d=5,r=5,p=0.001
#         1 pymatching <1m     971055        8597 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     988463        7574 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     998703        9678 d=5,r=5,p=0.01
#         1 pymatching <1m     999727        9944 d=5,r=5,p=0.021544346900318822
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 27 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     213295        9329 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     386351        7473 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     603439        3088 d=3,r=3,p=0.001
#         1 pymatching <1m     979247        4763 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     984367        5952 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     989487        7376 d=3,r=3,p=0.1
#         1 pymatching <1m     849199       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     875823        9994 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     909615        9933 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     945455        9669 d=5,r=5,p=0.001
#         1 pymatching <1m     971055        8597 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     988463        7574 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     998703        9678 d=5,r=5,p=0.01
#         1 pymatching <1m     999727        9944 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     999983        9992 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 27 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     213295        9329 d=3,r=3,p=0.00021544346900318845
#         1 pymatching <1m     386351        7473 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     603439        3088 d=3,r=3,p=0.001
#         1 pymatching <1m     979247        4763 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     984367        5952 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     989487        7376 d=3,r=3,p=0.1
#         1 pymatching <1m     787759       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     825647        9991 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     873775        9910 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     923951        9569 d=5,r=5,p=0.001
#         1 pymatching <1m     960815        8117 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     985391        6892 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     997679        9417 d=5,r=5,p=0.01
#         1 pymatching <1m     999727        9944 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     999727        9930 d=5,r=5,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 26 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     386351        7473 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     603439        3088 d=3,r=3,p=0.001
#         1 pymatching <1m     972079        2979 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     984367        5952 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     986415        6624 d=3,r=3,p=0.1
#         1 pymatching <1m     787759       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     825647        9991 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     873775        9910 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     923951        9569 d=5,r=5,p=0.001
#         1 pymatching <1m     960815        8117 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     985391        6892 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     996655        9139 d=5,r=5,p=0.01
#         1 pymatching <1m     998703        9680 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     999727        9930 d=5,r=5,p=0.046415888336127774
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 26 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     386351        7473 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     440623         287 d=3,r=3,p=0.001
#         1 pymatching <1m     972079        2979 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     979247        4695 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     986415        6624 d=3,r=3,p=0.1
#         1 pymatching <1m     787759       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     825647        9991 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     873775        9910 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     923951        9569 d=5,r=5,p=0.001
#         1 pymatching <1m     960815        8117 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     985391        6892 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     996655        9139 d=5,r=5,p=0.01
#         1 pymatching <1m     998703        9680 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     999727        9930 d=5,r=5,p=0.046415888336127774
#         1 pymatching   ?    1000000       10000 d=5,r=5,p=0.1
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 25 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     134447        6517 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     972079        2979 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     979247        4695 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     986415        6624 d=3,r=3,p=0.1
#         1 pymatching <1m     787759       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     825647        9991 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     873775        9910 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     923951        9569 d=5,r=5,p=0.001
#         1 pymatching <1m     960815        8117 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     981295        5989 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     995631        8855 d=5,r=5,p=0.01
#         1 pymatching <1m     998703        9680 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     999727        9930 d=5,r=5,p=0.046415888336127774
#         1 pymatching <1m     999983        9997 d=5,r=5,p=0.1
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 25 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     134447        6517 d=3,r=3,p=0.00046415888336127773
#         1 pymatching <1m     972079        2979 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     979247        4695 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     982319        5614 d=3,r=3,p=0.1
#         1 pymatching <1m     701743       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     754991        9986 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     823599        9877 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     894255        9402 d=5,r=5,p=0.001
#         1 pymatching <1m     960815        8117 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     981295        5989 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     995631        8855 d=5,r=5,p=0.01
#         1 pymatching <1m     998703        9680 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     999727        9930 d=5,r=5,p=0.046415888336127774
#         1 pymatching <1m     999727        9925 d=5,r=5,p=0.1
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.0001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 24 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching <1m     996655       10000 d=3,r=3,p=0.0001
#         1 pymatching <1m     961839         384 d=3,r=3,p=0.021544346900318822
#         1 pymatching <1m     979247        4695 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     982319        5614 d=3,r=3,p=0.1
#         1 pymatching <1m     701743       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     754991        9986 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     823599        9877 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     894255        9402 d=5,r=5,p=0.001
#         1 pymatching <1m     946479        7447 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     981295        5989 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     994607        8617 d=5,r=5,p=0.01
#         1 pymatching <1m     997679        9434 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     998703        9655 d=5,r=5,p=0.046415888336127774
#         1 pymatching <1m     999727        9925 d=5,r=5,p=0.1
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.0001
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 23 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching <1m     992559        9998 d=3,r=3,p=0.0001
#         1 pymatching <1m     979247        4695 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     982319        5614 d=3,r=3,p=0.1
#         1 pymatching <1m     701743       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     754991        9986 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     823599        9877 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     894255        9402 d=5,r=5,p=0.001
#         1 pymatching <1m     946479        7447 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     981295        5989 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     993583        8356 d=5,r=5,p=0.01
#         1 pymatching <1m     997679        9434 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     998703        9655 d=5,r=5,p=0.046415888336127774
#         1 pymatching <1m     999727        9925 d=5,r=5,p=0.1
#         1 pymatching <1m     996655       10000 d=7,r=7,p=0.0001
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 23 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching <1m     984367        9994 d=3,r=3,p=0.0001
#         1 pymatching <1m     973103        3158 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     982319        5614 d=3,r=3,p=0.1
#         1 pymatching <1m     701743       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     754991        9986 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     823599        9877 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     894255        9402 d=5,r=5,p=0.001
#         1 pymatching <1m     946479        7447 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     981295        5989 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     993583        8356 d=5,r=5,p=0.01
#         1 pymatching <1m     997679        9434 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     998703        9655 d=5,r=5,p=0.046415888336127774
#         1 pymatching <1m     999215        9810 d=5,r=5,p=0.1
#         1 pymatching <1m     991535       10000 d=7,r=7,p=0.0001
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.00021544346900318845
#         1 pymatching   ?    1000000       10000 d=7,r=7,p=0.00046415888336127773
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.001
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.002154434690031882
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.004641588833612777
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.01
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.021544346900318822
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.046415888336127774
#         0 pymatching ?·∞    1000000       10000 d=7,r=7,p=0.1
# 23 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching <1m     978223        9993 d=3,r=3,p=0.0001
#         1 pymatching <1m     973103        3158 d=3,r=3,p=0.046415888336127774
#         1 pymatching <1m     982319        5614 d=3,r=3,p=0.1
#         1 pymatching <1m     701743       10000 d=5,r=5,p=0.0001
#         1 pymatching <1m     754991        9986 d=5,r=5,p=0.00021544346900318845
#         1 pymatching <1m     823599        9877 d=5,r=5,p=0.00046415888336127773
#         1 pymatching <1m     894255        9402 d=5,r=5,p=0.001
#         1 pymatching <1m     946479        7447 d=5,r=5,p=0.002154434690031882
#         1 pymatching <1m     975151        4709 d=5,r=5,p=0.004641588833612777
#         1 pymatching <1m     992559        8103 d=5,r=5,p=0.01
#         1 pymatching <1m     996655        9196 d=5,r=5,p=0.021544346900318822
#         1 pymatching <1m     998703        9655 d=5,r=5,p=0.046415888336127774
# ...
#         5 pymatching <1m     337113        6656 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     970731        2748 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     970970        2645 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     337113        6656 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     970475        2691 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     970970        2645 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     200355        5944 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     970475        2691 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     970970        2645 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     200355        5944 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     970475        2691 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     970458        2525 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     200099        5943 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     970219        2622 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     970458        2525 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     200099        5943 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     970219        2622 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969690        2332 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     197027        5932 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969963        2565 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969690        2332 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     196771        5931 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969963        2565 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969690        2332 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     196771        5931 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969963        2565 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969178        2211 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     192675        5911 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969707        2506 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969178        2211 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     192675        5911 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969451        2438 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969178        2211 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     192419        5910 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969451        2438 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     969178        2211 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     192419        5910 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969451        2438 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968922        2149 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     192419        5910 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     969451        2438 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968666        2075 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     192163        5908 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     968171        2109 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968666        2075 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     186019        5868 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     968171        2109 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968666        2075 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     168017        5772 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     968171        2109 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968666        2075 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     167761        5767 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     968171        2109 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968666        2075 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     167761        5767 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967403        1927 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     968154        1940 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     167761        5767 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967403        1927 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     967386        1754 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     167505        5766 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967403        1927 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     967386        1754 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     133901        5572 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967403        1927 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     966362        1478 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     125709        5537 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967147        1866 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965850        1364 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m     125453        5534 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967147        1866 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965850        1364 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      98672        5398 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     967147        1866 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965850        1364 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      98672        5398 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     966635        1741 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965850        1364 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      98672        5398 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     964075        1084 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965594        1302 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      98416        5395 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     964075        1084 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965338        1241 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      98416        5395 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     963819        1020 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     965338        1241 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      98416        5395 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     963819        1020 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     963290         766 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      78681        5304 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     963819        1020 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     962778         652 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      67417        5255 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     963819        1020 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     962778         652 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      51168        5164 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     963819        1020 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     962778         652 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      39904        5108 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     963563         953 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     962778         652 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m      39904        5108 d=7,r=7,p=0.002154434690031882
#         5 pymatching <1m     962283         612 d=7,r=7,p=0.046415888336127774
#         6 pymatching <1m     962778         652 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         5 pymatching        <1m      39904        5108 d=7,r=7,p=0.002154434690031882
#         5 pymatching [draining]     957931        -451 d=7,r=7,p=0.046415888336127774
#         6 pymatching        <1m     962522         583 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         5 pymatching        <1m      36114        5097 d=7,r=7,p=0.002154434690031882
#         5 pymatching [draining]     957931        -451 d=7,r=7,p=0.046415888336127774
#         6 pymatching        <1m     962266         503 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         5 pymatching        <1m      28891        5054 d=7,r=7,p=0.002154434690031882
#         5 pymatching [draining]     957931        -451 d=7,r=7,p=0.046415888336127774
#         6 pymatching        <1m     962266         503 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         5 pymatching        <1m      15889        4977 d=7,r=7,p=0.002154434690031882
#         5 pymatching [draining]     956907        -703 d=7,r=7,p=0.046415888336127774
#         6 pymatching        <1m     962266         503 d=7,r=7,p=0.1
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         5 pymatching        <1m      11793        4956 d=7,r=7,p=0.002154434690031882
#         5 pymatching [draining]     955883        -965 d=7,r=7,p=0.046415888336127774
#         6 pymatching        <1m     962266         503 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m       6711        4928 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     962266         503 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m       5267        4921 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     961754         368 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m       5267        4921 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     961753         367 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m       5265        4921 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     961720         364 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m       1411        4904 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     960440          56 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m       1367        4904 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     960440          56 d=7,r=7,p=0.1
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         8 pymatching <1m        659        4898 d=7,r=7,p=0.002154434690031882
#         8 pymatching <1m     960440          56 d=7,r=7,p=0.1
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         8 pymatching [draining]     959672        -141 d=7,r=7,p=0.1
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         8 pymatching [draining]     958648        -403 d=7,r=7,p=0.1
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         8 pymatching [draining]     958136        -522 d=7,r=7,p=0.1
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         8 pymatching [draining]     957624        -640 d=7,r=7,p=0.1
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         8 pymatching [draining]     953528       -1686 d=7,r=7,p=0.1
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         8 pymatching [draining]     951736       -2140 d=7,r=7,p=0.1
# Plotting simulation results...
